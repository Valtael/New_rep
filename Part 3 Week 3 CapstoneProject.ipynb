# %% [markdown]
# <h1> Part 3 </h1>

# %%
# !conda install -c conda-forge folium=0.5.0 --yes
import folium
import pandas as pd
import numpy as np
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     altair-4.0.1               |             py_0         575 KB  conda-forge
#     certifi-2019.11.28         |           py36_0         149 KB  conda-forge
#     ca-certificates-2019.11.28 |       hecc5488_0         145 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     openssl-1.1.1d             |       h516909a_0         2.1 MB  conda-forge
#     ------------------------------------------------------------
# ...

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline 

from sklearn.cluster import KMeans 
from sklearn.preprocessing import StandardScaler
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
Tor_geo_data = pd.read_csv(r'Toronto_Neighborhoods_withltlng.csv')
Tor_geo_data.drop('Unnamed: 0', axis = 1, inplace = True)

# %% [markdown]
# Visualisation of the neighborhood data

# %%
tor_lat = 43.651070
tor_long = -79.347015

map_Toronto = folium.Map(location=[tor_lat, tor_long], zoom_start=11)


for lat, lng, label in zip(Tor_geo_data['Latitude'], Tor_geo_data['Longitude'], Tor_geo_data['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_Toronto)  
    
map_Toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Clustering based on location

# %%
x = Tor_geo_data [['Latitude','Longitude']]
num_clusters = 5

k_means = KMeans(init="k-means++", n_clusters=num_clusters, n_init=12)
k_means.fit(x)
labels = k_means.labels_

# %%
clust_data = Tor_geo_data
clust_data['Clusters'] = labels

# %% [markdown]
# Visualisation of the clusters

# %%
map_Tor_clusters = folium.Map(location=[tor_lat, tor_long], zoom_start=10)

x = np.arange(kclusters)
ys = [i + x**2 + (i*x)**4 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

markers_colors = []

for lat, lon, poi, cluster in zip(clust_data['Latitude'], clust_data['Longitude'], clust_data['Neighborhood'], clust_data['Clusters']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_Tor_clusters)
       
map_Tor_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
